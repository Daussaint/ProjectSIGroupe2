# %% [markdown]
# Idea from https://www.youtube.com/watch?v=fkgpvkqcoJc&ab_channel=DeepLearning_by_PhDScholar

# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('happy_lucas.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=1nz-WDhghGQBC4biwShQ9kYjvQMpO6smj
# To: /Users/Lucas/.deepface/weights/race_model_single_batch.zip
# 511MB [01:33, 5.46MB/s]
# Action: race: 100%|██████████| 4/4 [00:08<00:00,  2.25s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 5.270252211530234e-12,
#   'disgust': 2.5799562784975435e-23,
#   'fear': 8.259795463036007e-16,
#   'happy': 99.97718930244446,
#   'sad': 8.037110067098466e-12,
#   'surprise': 9.192592520523846e-09,
#   'neutral': 0.022812049428466707},
#  'dominant_emotion': 'happy',
#  'age': 22,
#  'gender': 'Man',
#  'race': {'asian': 0.0010089336976697792,
#   'indian': 0.0027546504143697702,
#   'black': 1.5694340499602366e-05,
#   'white': 94.77049049979335,
#   'middle eastern': 3.1039258440048507,
#   'latino hispanic': 2.121806770182463},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'
